# %%
#single line comment
# comments

# %%
#multi line comment

""""this is
a multiline 
comment"""
# Out:
# '"this                       is\na multiline \ncomment'

# %%
#variables

a = 20
name = "Jawahar"

# %%
print(a)
# Out:
# 20

# %%
b,c=20,30

# %%
print(b)
print(c)
# Out:
# 20
# 30

# %%
x=y=z =50

# %%
print(z)
# Out:
# 50

# %%
#keywords

# %%
import keyword

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  '__peg_parser__',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
# operators

# %%
5-3
# Out:
# 2

# %%
b-c
# Out:
# -10

# %%
5//2
# Out:
# 2

# %%
5%2
# Out:
# 1

# %%
not(2<5 and 2<10)
# Out:
# False

# %%
(2<5 and 2<10)
# Out:
# True

# %%
a = 10

# %%
print(a)
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
b=10.1

# %%
type(b)
# Out:
# float

# %%
c= 3+6j

# %%
print(type(c))
# Out:
# <class 'complex'>

# %%
# Out:
# float

# %%
a="This is Single line string"
b="""This is Multliline
string"""

# %%
print(type(a),type(b))
# Out:
# <class 'str'> <class 'str'>

# %%
print(a, '\n', b)
# Out:
# This is Single line string
#  This is Multliline
# string

# %%
#Indexing

# %%
a="Hello World!"

# %%
print(a[0])
# Out:
# H

# %%
print(a[6])
# Out:
# W

# %%
print(a[-1])
# Out:
# !

# %%
#Slicing

# %%
print(a[0:3:1])
# Out:
# Hel

# %%
print(a[1:8:2])
# Out:
# el o

# %%
print(a[:3])
# Out:
# Hel

# %%
print(a[3:])
# Out:
# lo World!

# %%
print(a[::])
# Out:
# Hello World!

# %%
a="Hello World!"

# %%
print(a[8:1:-1])
# Out:
# roW oll

# %%
print(a[::-1])
# Out:
# !dlroW olleH

# %%
#sring Funtion

# %%
a="hello world!"

# %%
print(a.capitalize())
# Out:
# Hello world!

# %%
print(a.center(20,'*'))
# Out:
# ****hello world!****

# %%
print(a.count("l",0,len(a)))
# Out:
# 3

# %%
print(len(a))
# Out:
# 12

# %%
print(a.endswith(" ",0,6))
# Out:
# True

# %%
a="Hello World!"

# %%
print(a.find('o'))
# Out:
# 4

# %%
print(a.rfind('o'))
# Out:
# 7

# %%
print(a.index('o'))
# Out:
# 4

# %%
print(a.rindex('o'))
# Out:
# 7

# %%
print(a.find('*'))
# Out:
# -1

# %%
print(a.index('*'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6564/2680033342.py in <module>
# ----> 1 print(a.index('*'))
#
# ValueError: substring not found

# %%
print(a.lower())
# Out:
# hello world!

# %%
print(a.upper())
# Out:
# HELLO WORLD!

# %%
print(a.split(' '))
# Out:
# ['Hello', 'World!']

# %%
words = ['Hello', 'World!']

# %%
print(' '.join(words))
# Out:
# Hello World!

# %%
a="  Hello World!   "

# %%
print(a.lstrip())
# Out:
# Hello World!

# %%
print(a.rstrip())
# Out:
#   Hello World!

# %%
print(a.strip())
# Out:
# Hello World!

# %%
print(a.swapcase())
# Out:
#   hELLO wORLD!

# %%
print(a.replace('l','L'))
# Out:
#   HeLLo WorLd!

# %%
print(len(a))
# Out:
# 17
